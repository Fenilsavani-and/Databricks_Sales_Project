# %%
import pyspark.sql.functions as F
from pyspark.sql.types import StringType, DateType
from pyspark.sql.functions import col, trim, length

# %%
RENAME_MAP = {
    "CID": "customer_id",
    "BDATE": "birthdate",
    "GEN": "gender"
}

# %% [markdown]
# Read from bronze table

# %%
df = spark.table("workspace.bronze.erp_cust_az12_raw")

# %% [markdown]
# ### 1. Trimming

# %%
for field in df.schema.fields:
    if isinstance(field.dataType, StringType):
        df = df.withColumn(field.name, trim(col(field.name)))

# %% [markdown]
# ### 2. Date formatting

# %%
# BDATE is already a DATE type in the bronze table, no transformation needed
pass

# %% [markdown]
# #### 3. Normalizing

# %% [markdown]
# #### 4. Renaming

# %%
for old_name, new_name in RENAME_MAP.items():
    df = df.withColumnRenamed(old_name, new_name)

# %% [markdown]
# Loading data in Silver Layer

# %%
(
    df.write
      .mode("overwrite")
      .format("delta")
      .saveAsTable("silver.erp_cust_info")
)

# %%
# %sql
select * from silver.erp_cust_info limit 10
